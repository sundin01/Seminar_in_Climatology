# %%
# General libs for file paths, data extraction, etc
from glob import glob
from pathlib import Path
from os.path import basename
import zipfile # To extract zipfiles
import urllib3 
urllib3.disable_warnings() # Disable warnings for data download via API

# Libraries for working with multi-dimensional arrays
import numpy as np
import xarray as xr
import xarray.plot as xplot
import pandas as pd

# Libraries for plotting and visualising data
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature

from datetime import datetime

import xclim as xc

# %%
file='/scratch2/mfeldmann/seminar_mars/HW_EU_20230711.nc'
ds = xr.open_dataset(file)

# %%
#Map of temperature at step 0: 0 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t.sel(isobaricInhPa=850,step=ds.step[0]).plot( cmap=cmap);

# %%
#Map of temperature at step 1: 0 days 12:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t.sel(isobaricInhPa=850,step=ds.step[1]).plot( cmap=cmap);

# %%
#Map of temperature at step 2: 0 days 18:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t.sel(isobaricInhPa=850,step=ds.step[2]).plot( cmap=cmap);

# %%
#Map of temperature at step 3: 1 days 00:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t.sel(isobaricInhPa=850,step=ds.step[3]).plot( cmap=cmap);

# %%
#Map of temperature at step 4: 1 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t.sel(isobaricInhPa=850,step=ds.step[4]).plot( cmap=cmap);

# %%
#Map of 2m temperature at step 0: 0 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-10, 40, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[0]).plot( cmap=cmap);

# %%
#Map of 2m temperature at step 1: 0 days 12:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[1]).plot( cmap=cmap);

# %%
#Map of 2m temperature at step 2: 0 days 18:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[2]).plot( cmap=cmap);

# %%
#Map of 2m temperature at step 3: 1 days 00:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[3]).plot( cmap=cmap);

# %%
#Map of 2m temperature at step 4: 1 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-180, 180, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[4]).plot( cmap=cmap);

# %%
#### Cut to Region, K

# %%
#Map of 2m temperature in K at step 0: 0 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[0]).plot( cmap=cmap);

# %%
#Map of 2m temperature in K at step 1: 0 days 12:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[1]).plot( cmap=cmap);

# %%
#Map of 2m temperature in K at step 2: 0 days 18:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[2]).plot( cmap=cmap);

# %%
#Map of 2m temperature in K at step 3: 1 days 00:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[3]).plot( cmap=cmap);

# %%
#Map of 2m temperature in K at step 4: 1 days 06:00:00
import matplotlib.colors as colors
#-- Color schemes
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
ds.t2.sel(step=ds.step[4]).plot( cmap=cmap);

# %%
#### Cut to Region, C

# %%
#Map of 2m temperature in C at step 0: 0 days 06:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[0])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
#Map of 2m temperature in C at step 1: 0 days 12:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[1])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
#Map of 2m temperature in C at step 2: 0 days 18:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[2])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
#Map of 2m temperature in C at step 3: 1 days 00:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[3])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
#Map of 2m temperature in C at step 4: 1 days 06:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[4])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
#Map of 2m temperature in C at step 5: 1 days 12:00:00
vmin = 12
vmax = 48
cmap = colors.LinearSegmentedColormap.from_list('mycmap', ['blue', 'lightblue', 'white', 'orange', 'red'])
fig = plt.figure(figsize=[20,4])
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)
ax.set_extent([-30, 30, 20, 50])
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE, linestyle='-');
(ds.t2.sel(step=ds.step[5])-273.15).plot(ax=ax, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
# Means/Weighted Means

# %%
ds.t2.resample(step='1D').mean()
# Out:
# <xarray.DataArray 't2' (step: 4, latitude: 121, longitude: 1440)>
# array([[[289.28873, 289.4601 , 289.66177, ..., 289.70572, 289.65933,
#          289.7316 ],
#         [289.90103, 290.40543, 290.70328, ..., 290.007  , 289.94107,
#          290.027  ],
#         [290.73257, 291.04996, 291.19742, ..., 290.4733 , 290.56656,
#          290.72916],
#         ...,
#         [309.74478, 309.54556, 309.58853, ..., 310.4738 , 310.45474,
#          310.2941 ],
#         [309.65884, 309.6608 , 309.8151 , ..., 310.58902, 310.46695,
#          310.2521 ],
#         [309.8854 , 309.82584, 310.04703, ..., 310.8268 , 310.61978,
#          310.51138]],
#
#        [[289.13318, 289.21472, 289.33484, ..., 289.40857, 289.34656,
#          289.43103],
#         [289.63904, 289.81775, 289.9076 , ..., 289.7201 , 289.70935,
#          289.78796],
#         [290.15808, 290.2079 , 290.16638, ..., 290.16345, 290.29626,
#          290.39   ],
# ...
# ...

# %%
# Define the area of interest
area = [75, -35, 35, 40]  # North, West, South, East
temp = ds['t2']
# Extract the subset for the specified area
temp_area = temp.sel(latitude=slice(area[0], area[2]), longitude=slice(area[1], area[3]))
# Calculate the mean temperature for the area for each time step
mean_temperature = temp_area.mean(dim=('latitude', 'longitude'))
mean_temperature
# Out:
# <xarray.DataArray 't2' (step: 14)>
# array([298.53427, 294.38763, 296.2011 , 300.74817, 298.44894, 294.68326,
#        296.53473, 300.83798, 298.46814, 294.6325 , 296.3859 , 301.206  ,
#        299.12433, 295.0516 ], dtype=float32)
# Coordinates:
#   * step               (step) timedelta64[ns] 0 days 06:00:00 ... 3 days 12:0...
#     valid_time         (step) datetime64[ns] ...
#     time               datetime64[ns] ...
#     meanSea            float64 ...
#     heightAboveGround  float64 ...
